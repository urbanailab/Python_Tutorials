# %% [markdown]
# Now, you shall see that the analytical fairness consists of two components: definition of fairness and the analytics. The definition is more conceptual than computational, and you have obtained the ALL the scripts necessary for analytics. Therefore, in today's lab, you can practice coding by using all the past scripts and make fairness evaluation.

# %% [markdown]
# # Exercise 1. Fairness in statistical modeling.
#
# 1. Choose the definition of fairness (major premise)
# 2. Choose the analytical context, e.g. X & Y (minor premise)
# 3. Make a conclusion.
#
# Note: you could use linear regressions with Y as a continuous variable.

# %% [markdown]
# # Exercise 2. Fairness in machine learning.
# 1. Choose the definition of fairness (major premise) - Please simply use accuracy disparity.
# 2. Choose the analytical context, e.g. Y, X, and ML models (minor premise)
# 3. Make a conclusion.
#
# Note: you shall use classification tasks so that both Y and socially sensitive group (X) are discrete binary variables.
